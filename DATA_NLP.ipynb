# %%
import pandas as pd

# %%
#name = 'covid_main_raw_to_publish.csv'
#name = 'test_insample_tagged_raw_to_publish.csv'
name = 'test_outsample_tagged_raw_to_publish.csv'

# %%
df = pd.read_csv(name)
print(display(df.head()))
# Out:
#    Unnamed: 0   value source   doc_id  emotion_id  sen_score  sen_binary  \
# 0           0   שלילי   ynet  index_0           0       -0.5          -1
# 1           1   שלילי   ynet  index_0           0       -0.5          -1
# 2           2   שלילי   ynet  index_0           0       -0.5          -1
# 3           3  ניטרלי   ynet  index_0           0        0.0           0
# 4           4   שלילי   ynet  index_0           0       -0.5          -1
#
#    emotion emotion_en    avg_Ao  krippendorff_alpha  agreed_score  \
# 0  סנטימנט  sentiment -0.107143                 0.0           NaN
# 1  סנטימנט  sentiment -0.107143                 0.0           NaN
# 2  סנטימנט  sentiment -0.107143                 0.0           NaN
# 3  סנטימנט  sentiment -0.107143                 0.0           NaN
# 4  סנטימנט  sentiment -0.107143                 0.0           NaN
#
#                                            talkbacks  \
# 0   קישקוש מוחלט - בנט אלוף החארטה . אני לא מבוחר...
# ...

# %%
print(display(df[0:50]))
# Out:
#     Unnamed: 0                       value source   doc_id  emotion_id  \
# 0            0                       שלילי   ynet  index_0           0
# 1            1                       שלילי   ynet  index_0           0
# 2            2                       שלילי   ynet  index_0           0
# 3            3                      ניטרלי   ynet  index_0           0
# 4            4                       שלילי   ynet  index_0           0
# 5            5                  שלילי מאוד   ynet  index_0           0
# 6            6                  שלילי מאוד   ynet  index_0           0
# 7            7                       חיובי   ynet  index_0           0
# 8            8                לא מתבטא כלל   ynet  index_0           1
# 9            9     מתבטא בתגובה באופן חלקי   ynet  index_0           1
# 10          10     מתבטא בתגובה באופן חלקי   ynet  index_0           1
# 11          11     מתבטא בתגובה באופן חלקי   ynet  index_0           1
# ...

# %%
df.drop(df.loc[df['emotion_en']=='sentiment'].index, inplace=True)
print(display(df.head()))
# Out:
#     Unnamed: 0                    value source   doc_id  emotion_id  \
# 8            8             לא מתבטא כלל   ynet  index_0           1
# 9            9  מתבטא בתגובה באופן חלקי   ynet  index_0           1
# 10          10  מתבטא בתגובה באופן חלקי   ynet  index_0           1
# 11          11  מתבטא בתגובה באופן חלקי   ynet  index_0           1
# 12          12             לא מתבטא כלל   ynet  index_0           1
#
#     sen_score  sen_binary             emotion   emotion_en    avg_Ao  \
# 8         0.0          -1  ציפייה, הבעת עניין  expectation -1.285714
# 9         0.5           1  ציפייה, הבעת עניין  expectation -1.285714
# 10        0.5           1  ציפייה, הבעת עניין  expectation -1.285714
# 11        0.5           1  ציפייה, הבעת עניין  expectation -1.285714
# 12        0.0          -1  ציפייה, הבעת עניין  expectation -1.285714
#
#     krippendorff_alpha  agreed_score  \
# 8                  0.0           NaN
# 9                  0.0           NaN
# ...

# %%
print (display(df[(df['agreed_score']<1) & (df['agreed_score']>0)]))
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, value, source, doc_id, emotion_id, sen_score, sen_binary, emotion, emotion_en, avg_Ao, krippendorff_alpha, agreed_score, talkbacks, title, date]
# Index: []
# None

# %%
print (display(df[(df['agreed_score']!=1)]))
# Out:
#        Unnamed: 0                    value source     doc_id  emotion_id  \
# 8               8             לא מתבטא כלל   ynet    index_0           1
# 9               9  מתבטא בתגובה באופן חלקי   ynet    index_0           1
# 10             10  מתבטא בתגובה באופן חלקי   ynet    index_0           1
# 11             11  מתבטא בתגובה באופן חלקי   ynet    index_0           1
# 12             12             לא מתבטא כלל   ynet    index_0           1
# ...           ...                      ...    ...        ...         ...
# 43591       43591             לא מתבטא כלל   ynet  index_478           8
# 43592       43592             לא מתבטא כלל   ynet  index_478           8
# 43593       43593  מתבטא בתגובה באופן חלקי   ynet  index_478           8
# 43594       43594             לא מתבטא כלל   ynet  index_478           8
# 43595       43595  מתבטא בתגובה באופן חלקי   ynet  index_478           8
#
#        sen_score  sen_binary             emotion   emotion_en    avg_Ao  \
# ...

# %%
df.drop(df.loc[df['agreed_score']!=1].index, inplace=True)
print(display(df[0:30]))
# Out:
#      Unnamed: 0                       value source   doc_id  emotion_id  \
# 552         552  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 553         553  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 554         554     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 555         555  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 556         556  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 557         557  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 558         558  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 559         559     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 560         560     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 561         561     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 562         562  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 563         563  מתבטא בתגובה באופן משמעותי   ynet  index_6           3
# ...

# %%
print(display(df[0:30]))
# Out:
#      Unnamed: 0                       value source   doc_id  emotion_id  \
# 552         552  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 553         553  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 554         554     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 555         555  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 556         556  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 557         557  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 558         558  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 559         559     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 560         560     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 561         561     מתבטא בתגובה באופן חלקי   ynet  index_6           2
# 562         562  מתבטא בתגובה באופן משמעותי   ynet  index_6           2
# 563         563  מתבטא בתגובה באופן משמעותי   ynet  index_6           3
# ...

# %%
df =df.drop(['Unnamed: 0','title','date','sen_binary','avg_Ao','krippendorff_alpha','agreed_score','sen_score','doc_id','source','value'],axis = 1)
print(display(df.head()))
# Out:
#      emotion_id        emotion emotion_en  \
# 552           2  שמחה, התלהבות      happy
# 553           2  שמחה, התלהבות      happy
# 554           2  שמחה, התלהבות      happy
# 555           2  שמחה, התלהבות      happy
# 556           2  שמחה, התלהבות      happy
#
#                                              talkbacks
# 552   All the power to you . אנחנו מאמינים בך וסומכ...
# 553   All the power to you . אנחנו מאמינים בך וסומכ...
# 554   All the power to you . אנחנו מאמינים בך וסומכ...
# 555   All the power to you . אנחנו מאמינים בך וסומכ...
# 556   All the power to you . אנחנו מאמינים בך וסומכ...
# None

# %%
df = df.drop_duplicates()
print(display(df.head()))
# Out:
#       emotion_id         emotion emotion_en  \
# 552            2   שמחה, התלהבות      happy
# 563            3       הבעת אמון      trust
# 673            4        חשש, פחד       fear
# 706            7  סלידה, אי אמון    disgust
# 1048           3       הבעת אמון      trust
#
#                                               talkbacks
# 552    All the power to you . אנחנו מאמינים בך וסומכ...
# 563    All the power to you . אנחנו מאמינים בך וסומכ...
# 673      ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 706      ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 1048                 כל הכבוד, בבחירות הקול שלי עם בנט
# None

# %%
df = df.reset_index(drop=True)
print(display(df.head()))
# Out:
#    emotion_id         emotion emotion_en  \
# 0           2   שמחה, התלהבות      happy
# 1           3       הבעת אמון      trust
# 2           4        חשש, פחד       fear
# 3           7  סלידה, אי אמון    disgust
# 4           3       הבעת אמון      trust
#
#                                            talkbacks
# 0   All the power to you . אנחנו מאמינים בך וסומכ...
# 1   All the power to you . אנחנו מאמינים בך וסומכ...
# 2     ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 3     ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 4                 כל הכבוד, בבחירות הקול שלי עם בנט
# None

# %%
df['emotion_id'] = df['emotion_id'] -1

# %%
print(display(df[0:10]))
# Out:
#    emotion_id             emotion   emotion_en  \
# 0           1       שמחה, התלהבות        happy
# 1           2           הבעת אמון        trust
# 2           3            חשש, פחד         fear
# 3           6      סלידה, אי אמון      disgust
# 4           2           הבעת אמון        trust
# 5           0  ציפייה, הבעת עניין  expectation
# 6           1       שמחה, התלהבות        happy
# 7           2           הבעת אמון        trust
# 8           6      סלידה, אי אמון      disgust
# 9           7            זעם, כעס        anger
#
#                                            talkbacks
# 0   All the power to you . אנחנו מאמינים בך וסומכ...
# 1   All the power to you . אנחנו מאמינים בך וסומכ...
# 2     ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 3     ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 4                 כל הכבוד, בבחירות הקול שלי עם בנט
# 5                    כל הכבוד המשך כך בעשייה חיובית
# 6                    כל הכבוד המשך כך בעשייה חיובית
# ...

# %%
df = df.drop_duplicates(subset=['talkbacks'])
print(display(df.head()))
# Out:
#    emotion_id             emotion   emotion_en  \
# 0           1       שמחה, התלהבות        happy
# 2           3            חשש, פחד         fear
# 4           2           הבעת אמון        trust
# 5           0  ציפייה, הבעת עניין  expectation
# 8           6      סלידה, אי אמון      disgust
#
#                                            talkbacks
# 0   All the power to you . אנחנו מאמינים בך וסומכ...
# 2     ככה נראת תחילתה של האנרכיה, תחי מדינת ישראל
# 4                 כל הכבוד, בבחירות הקול שלי עם בנט
# 5                    כל הכבוד המשך כך בעשייה חיובית
# 8      בנט אם ביבי תתן לך לטיפה תחזור אליו כמו פודל
# None

# %%
import seaborn as sns
sns.countplot(x='emotion_en',data=df)
# Out:
# <AxesSubplot:xlabel='emotion_en', ylabel='count'>

# %%
name = 'data_'+ name
print(name)
# Out:
# data_test_outsample_tagged_raw_to_publish.csv

# %%
df.to_csv(name)
